# %% [markdown]
# ### Research Questions
# 1. which genres are the most common (number of movies made)
# 2. which genres have high avg. budget and revenue?
# 2. which genres have high avg. profit?
# 3. which genres have high avg. popularity?
# 4. which genres have highest number of movies with an voting avg. >=8 ?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv(r"C:\Users\User\Downloads\imdb_movies.csv")
movies
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
pd.set_option('display.max.rows', 11000)
pd.set_option('display.max.rows', 22)

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
movies[movies.duplicated()]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  ...  \
# 2090  Dwight H. Little  Survival is no game  ...
#
#                                                overview runtime  \
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date vote_count  vote_average  release_year  budget_adj  \
# 2090      3/20/10        110           5.0          2010  30000000.0
#
#       revenue_adj
# 2090     967000.0
#
# [1 rows x 21 columns]

# %%
movies.drop_duplicates(inplace = True)

# %%
movies[movies.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, popularity, budget, revenue, original_title, cast, homepage, director, tagline, keywords, overview, runtime, genres, production_companies, release_date, vote_count, vote_average, release_year, budget_adj, revenue_adj]
# Index: []
#
# [0 rows x 21 columns]

# %%
movies.dropna(subset=['genres'], inplace = True)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10842 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10842 non-null  int64
#  1   imdb_id               10834 non-null  object
#  2   popularity            10842 non-null  float64
#  3   budget                10842 non-null  int64
#  4   revenue               10842 non-null  int64
#  5   original_title        10842 non-null  object
#  6   cast                  10767 non-null  object
#  7   homepage              2931 non-null   object
#  8   director              10800 non-null  object
#  9   tagline               8036 non-null   object
#  10  keywords              9367 non-null   object
#  11  overview              10839 non-null  object
#  12  runtime               10842 non-null  int64
#  13  genres                10842 non-null  object
#  14  production_companies  9826 non-null   object
# ...

# %% [markdown]
# now we have drop the null values in the genres column and it the same lenght as all columns

# %%
movies['profit'] = movies['revenue'] - movies['budget']

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
# let's get columns we need for the analysis
movie_genre = movies[['popularity', 'budget','revenue', 'original_title', 'runtime', 'genres','release_date','vote_count','vote_average','profit']]

# %%
movie_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15        5562
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15        6185
# 2         Adventure|Science Fiction|Thriller      3/18/15        2480
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15        5292
# 4                      Action|Crime|Thriller       4/1/15        2947
#
#    vote_average      profit
# 0           6.5  1363528810
# 1           7.1   228436354
# ...

# %%
from pandas import Series, DataFrame

# %%
movie_genre['genres'].str.split('|').apply(Series,1).stack()
# Out:
# 0      0             Action
#        1          Adventure
#        2    Science Fiction
#        3           Thriller
# 1      0             Action
#                  ...
# 10863  0            Mystery
#        1             Comedy
# 10864  0             Action
#        1             Comedy
# 10865  0             Horror
# Length: 26955, dtype: object

# %%
split = movie_genre['genres'].str.split('|').apply(Series,1).stack()
split.index = split.index.droplevel(-1)
split
# Out:
# 0                 Action
# 0              Adventure
# 0        Science Fiction
# 0               Thriller
# 1                 Action
#               ...
# 10863            Mystery
# 10863             Comedy
# 10864             Action
# 10864             Comedy
# 10865             Horror
# Length: 26955, dtype: object

# %%
split.name ='genres_split'
del movie_genre['genres']
movie_genre = movie_genre.join(split)

# %%
movie_genre
# Out:
#        popularity     budget     revenue            original_title  runtime  \
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 1       28.419936  150000000   378436354        Mad Max: Fury Road      120
# ...           ...        ...         ...                       ...      ...
# 10863    0.065141          0           0       Beregis Avtomobilya       94
# 10863    0.065141          0           0       Beregis Avtomobilya       94
# 10864    0.064317          0           0    What's Up, Tiger Lily?       80
# 10864    0.064317          0           0    What's Up, Tiger Lily?       80
# 10865    0.035919      19000           0  Manos: The Hands of Fate       74
#
# ...

# %% [markdown]
# ### 1. Which genres are the most common (number of movies made)

# %%
 movie_genre.groupby('genres_split')['original_title'].count().sort_values(ascending = False)
# Out:
# genres_split
# Drama              4760
# Comedy             3793
# Thriller           2907
# Action             2384
# Romance            1712
# Horror             1637
# Adventure          1471
# Crime              1354
# Family             1231
# Science Fiction    1229
# Fantasy             916
# Mystery             810
# Animation           699
# Documentary         520
# Music               408
# History             334
# War                 270
# Foreign             188
# TV Movie            167
# Western             165
# Name: original_title, dtype: int64

# %% [markdown]
# since this one is series we need our result in a dataframe so let's fix it below

# %%
genres_count = pd.DataFrame(movie_genre.groupby('genres_split').original_title.nunique()).sort_values('original_title',ascending = True)

# %%
genres_count
# Out:
#                  original_title
# genres_split
# Drama                      4672
# Comedy                     3750
# Thriller                   2841
# Action                     2339
# Romance                    1686
# Horror                     1580
# Adventure                  1442
# Crime                      1337
# Family                     1211
# Science Fiction            1207
# Fantasy                     899
# Mystery                     796
# Animation                   697
# Documentary                 520
# Music                       403
# History                     331
# War                         269
# Foreign                     188
# TV Movie                    167
# Western                     163

# %%
genres_count['original_title'].plot.pie(title = 'Movies Per Genre in %', autopct='%1.1f%%', figsize=(10,10))
plt.show()

# %%
genres_count['original_title'].plot.barh(title = 'Movies Per Genre', color = 'DarkBlue', figsize=(10,9))
plt.show()

# %% [markdown]
# Drama is the most common genre movies made

# %% [markdown]
# ### 2. Which genres have high avg. budget and revenue?

# %%
genres_avg = movie_genre.groupby('genres_split').mean()
# let's change the scientific notation to float
pd.options.display.float_format = '{:2f}' .format
genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# Action             0.926274 27727820.331376  72794732.002517 104.917785
# Adventure          1.154259 37543694.530931 113137861.069341 106.173351
# Animation          0.852182 23159781.606581  75256062.223176  68.181688
# Comedy             0.592607 13297915.618244  37526242.072238  96.745057
# Crime              0.744930 17663801.124815  42368661.645495 106.917282
# Documentary        0.181432   577149.148077   2041106.994231 102.651923
# Drama              0.591495 11880717.773529  29232255.725840 110.478151
# Family             0.786668 23359337.420796  72433176.373680  89.603574
# Fantasy            0.992840 32612585.348253  96313657.081878 100.736900
# Foreign            0.191496  1451434.925532   1520459.835106 107.228723
# History            0.575936 18594919.302395  32011793.215569 136.206587
# Horror             0.465357  6226529.210751  16822808.624313  94.424557
# ...

# %%
genres_avg.sort_values('budget', ascending=True, inplace=True)

# %%
genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# Adventure          1.154259 37543694.530931 113137861.069341 106.173351
# Fantasy            0.992840 32612585.348253  96313657.081878 100.736900
# Action             0.926274 27727820.331376  72794732.002517 104.917785
# Science Fiction    1.001548 24972680.524003  70140558.034174  99.419854
# Family             0.786668 23359337.420796  72433176.373680  89.603574
# Animation          0.852182 23159781.606581  75256062.223176  68.181688
# War                0.727683 20891886.103704  47605183.300000 127.625926
# Western            0.590615 18974107.975758  28568709.284848 117.575758
# History            0.575936 18594919.302395  32011793.215569 136.206587
# Crime              0.744930 17663801.124815  42368661.645495 106.917282
# Thriller           0.741563 17207693.769178  41728417.543860 103.247678
# Mystery            0.690012 16119270.062963  40217566.661728 105.928395
# ...

# %%
genres_avg[['budget', 'revenue']].plot.barh(title = 'Budget and Revenue by Genre', color =( 'DarkBlue', 'c'), figsize=(10,9))
plt.show()

# %% [markdown]
# the highest Budget and revenue were made in the adventure movies

# %% [markdown]
# ### 2.5 which genres have high avg. profit?

# %%
genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# TV Movie           0.270896   267664.670659    251497.005988  91.982036
# Documentary        0.181432   577149.148077   2041106.994231 102.651923
# Foreign            0.191496  1451434.925532   1520459.835106 107.228723
# Horror             0.465357  6226529.210751  16822808.624313  94.424557
# Music              0.487321  9438627.549020  28571768.691176 105.137255
# Drama              0.591495 11880717.773529  29232255.725840 110.478151
# Romance            0.592082 12531271.847547  35691972.327103 106.891355
# Comedy             0.592607 13297915.618244  37526242.072238  96.745057
# Mystery            0.690012 16119270.062963  40217566.661728 105.928395
# Thriller           0.741563 17207693.769178  41728417.543860 103.247678
# Crime              0.744930 17663801.124815  42368661.645495 106.917282
# History            0.575936 18594919.302395  32011793.215569 136.206587
# ...

# %%
genres_avg.sort_values('profit', ascending=True, inplace=True)

# %%
genres_avg['profit'].plot.barh(title = 'profit by Genre', color =( 'DarkBlue'), figsize=(10,9))
plt.show()

# %% [markdown]
# The highest profit genre is Adventure, Fantasy and Animation

# %% [markdown]
# ### 3. which genres ahve high avg. popularity?

# %%
genres_avg.sort_values('popularity', ascending=True, inplace=True)

# %%
genres_avg['popularity'].plot.barh(title = 'popularity by Genre', color =( 'DarkBlue'), figsize=(10,9))
plt.show()

# %% [markdown]
# The highest avg. popularity is Adventure

# %% [markdown]
# ### 4. Which genre have the highest number with an voting avg. >=8?

# %%
movie_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#   release_date  vote_count  vote_average      profit     genres_split
# 0       6/9/15        5562      6.500000  1363528810           Action
# 0       6/9/15        5562      6.500000  1363528810        Adventure
# 0       6/9/15        5562      6.500000  1363528810  Science Fiction
# 0       6/9/15        5562      6.500000  1363528810         Thriller
# 1      5/13/15        6185      7.100000   228436354           Action

# %%
vote_fifty = movie_genre[(movie_genre['vote_count'] >= 50) & (movie_genre['vote_average']>=8)]
vote_zero = movie_genre[movie_genre['vote_average']>=8]

# %%
genres_vote = pd.DataFrame(vote_fifty.groupby('genres_split').vote_average.nunique()).sort_values('vote_average',ascending = True)

# %%
genres_vote
# Out:
#                  vote_average
# genres_split
# Fantasy                     1
# Science Fiction             1
# Animation                   1
# Mystery                     1
# Horror                      1
# Family                      1
# Romance                     2
# Music                       2
# History                     2
# Action                      2
# Comedy                      2
# Adventure                   2
# Thriller                    2
# War                         2
# Crime                       4
# Drama                       5
# Documentary                 5

# %%
genres_vote['vote_average'].plot.barh(title = 'vote_average by Genre', color =( 'DarkBlue'), figsize=(10,9))
plt.show()

# %% [markdown]
# ### Research Hypothesis
# 1. the best movies according to vote avg. return high profit and revenue.
# 2. the best movies according to popularity return high profit and revenue
# 3. highly budgeted movies return high revenue and profit
# 4. Highly budgeted movies have a high popularity

# %%
movies.drop_duplicates(inplace = True)
movies['profit'] = movies['revenue'] - movies['budget']
movies_genre = movies[['popularity', 'budget','revenue', 'original_title', 'runtime', 'genres','release_date','vote_count','vote_average','profit']]

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15        5562
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15        6185
# 2         Adventure|Science Fiction|Thriller      3/18/15        2480
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15        5292
# 4                      Action|Crime|Thriller       4/1/15        2947
#
#    vote_average      profit
# 0      6.500000  1363528810
# 1      7.100000   228436354
# ...

# %% [markdown]
# ### 1. the best movies according to vote avg. return high profit and revenue

# %%
movies_counted = movies_genre[movie_genre['vote_count']>=50]

# %%
movies_counted.corr(method = 'spearman')
# Out:
#               popularity    budget  revenue  runtime  vote_count  \
# popularity      1.000000  0.485149 0.588739 0.230518    0.768966
# budget          0.485149  1.000000 0.714828 0.360230    0.554586
# revenue         0.588739  0.714828 1.000000 0.341707    0.682656
# runtime         0.230518  0.360230 0.341707 1.000000    0.263460
# vote_count      0.768966  0.554586 0.682656 0.263460    1.000000
# vote_average    0.188670 -0.044440 0.111731 0.285514    0.284470
# profit          0.498117  0.334390 0.842221 0.212060    0.583602
#
#               vote_average   profit
# popularity        0.188670 0.498117
# budget           -0.044440 0.334390
# revenue           0.111731 0.842221
# runtime           0.285514 0.212060
# vote_count        0.284470 0.583602
# vote_average      1.000000 0.198308
# profit            0.198308 1.000000

# %%
movies_counted.plot.scatter(x='vote_average', y='profit')
plt.show()

# %%
sns.regplot(x='vote_average', y='profit', data=movies_counted, line_kws={'color':'red'})
plt.show()

# %%
sns.regplot(x='vote_average', y='revenue', data=movies_counted, line_kws={'color':'red'})
plt.show()

# %% [markdown]
# ### 2. the best movies according to popularity return high profit and revenue

# %%
movies_counted.corr(method = 'spearman')
# Out:
#               popularity    budget  revenue  runtime  vote_count  \
# popularity      1.000000  0.485149 0.588739 0.230518    0.768966
# budget          0.485149  1.000000 0.714828 0.360230    0.554586
# revenue         0.588739  0.714828 1.000000 0.341707    0.682656
# runtime         0.230518  0.360230 0.341707 1.000000    0.263460
# vote_count      0.768966  0.554586 0.682656 0.263460    1.000000
# vote_average    0.188670 -0.044440 0.111731 0.285514    0.284470
# profit          0.498117  0.334390 0.842221 0.212060    0.583602
#
#               vote_average   profit
# popularity        0.188670 0.498117
# budget           -0.044440 0.334390
# revenue           0.111731 0.842221
# runtime           0.285514 0.212060
# vote_count        0.284470 0.583602
# vote_average      1.000000 0.198308
# profit            0.198308 1.000000

# %%
plt.figure(figsize=(10,5))
sns.regplot(x='popularity', y='revenue', data=movies_counted, line_kws={'color':'red'})
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.regplot(x='popularity', y='profit', data=movies_counted, line_kws={'color':'red'})
plt.show()

# %% [markdown]
# ### 3. highly budgeted movies return high revenue and profit

# %%
movies_counted.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15        5562
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15        6185
# 2         Adventure|Science Fiction|Thriller      3/18/15        2480
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15        5292
# 4                      Action|Crime|Thriller       4/1/15        2947
#
#    vote_average      profit
# 0      6.500000  1363528810
# 1      7.100000   228436354
# ...

# %%
plt.figure(figsize=(10,5))
sns.regplot(x='budget', y='popularity', data=movies_counted, line_kws={'color':'red'})
plt.show()

# %%
movies_genre
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#        runtime                                     genres release_date  \
# ...
